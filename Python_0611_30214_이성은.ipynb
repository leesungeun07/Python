# %% [markdown]
# ## 공공데이터

# %%
import pandas as pd

# %%
path = r"C:\Users\user\Desktop\covid.csv"
pd.read_csv(path, encoding = 'cp949')
# Out:
#             시군구       의료기관명  진료과수  병상수 국민안심병원 여부 감염병전담기관 여부 감염병전담기관 외래진료 가능여부
# 0       강원도 강릉시      강릉동인병원    21  608       NaN        NaN               NaN
# 1       강원도 강릉시     박정빈외과의원     1    0       NaN        NaN               NaN
# 2       강원도 강릉시     이명호내과의원     1    0       NaN        NaN               NaN
# 3       강원도 고성군       세브란의원     4    0       NaN        NaN               NaN
# 4       강원도 동해시  근로복지공단동해병원    10  499         Y        NaN               NaN
# ..          ...         ...   ...  ...       ...        ...               ...
# 314  충북 청주시 청원구      초정노인병원     3  150       NaN        NaN               NaN
# 315  충북 청주시 흥덕구      청주현대병원     4  150       NaN        NaN               NaN
# 316      충북 충주시     건국대충주병원    23  464         Y        NaN               NaN
# 317      충북 충주시      송원요양병원     2  105       NaN        NaN               NaN
# 318      충북 충주시   충주시노인전문병원     4  120       NaN        NaN               NaN
#
# [319 rows x 7 columns]

# %%
pd.read_csv(path, encoding = 'cp949').head()
# Out:
#        시군구       의료기관명  진료과수  병상수 국민안심병원 여부 감염병전담기관 여부 감염병전담기관 외래진료 가능여부
# 0  강원도 강릉시      강릉동인병원    21  608       NaN        NaN               NaN
# 1  강원도 강릉시     박정빈외과의원     1    0       NaN        NaN               NaN
# 2  강원도 강릉시     이명호내과의원     1    0       NaN        NaN               NaN
# 3  강원도 고성군       세브란의원     4    0       NaN        NaN               NaN
# 4  강원도 동해시  근로복지공단동해병원    10  499         Y        NaN               NaN

# %%
pd.read_csv(path, encoding = 'cp949').tail()
# Out:
#             시군구      의료기관명  진료과수  병상수 국민안심병원 여부 감염병전담기관 여부 감염병전담기관 외래진료 가능여부
# 314  충북 청주시 청원구     초정노인병원     3  150       NaN        NaN               NaN
# 315  충북 청주시 흥덕구     청주현대병원     4  150       NaN        NaN               NaN
# 316      충북 충주시    건국대충주병원    23  464         Y        NaN               NaN
# 317      충북 충주시     송원요양병원     2  105       NaN        NaN               NaN
# 318      충북 충주시  충주시노인전문병원     4  120       NaN        NaN               NaN

# %%
pd.read_csv(path, encoding = 'cp949').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 7 columns):
# 시군구                  319 non-null object
# 의료기관명                319 non-null object
# 진료과수                 319 non-null int64
# 병상수                  319 non-null int64
# 국민안심병원 여부            72 non-null object
# 감염병전담기관 여부           26 non-null object
# 감염병전담기관 외래진료 가능여부    26 non-null object
# dtypes: int64(2), object(5)
# memory usage: 17.6+ KB

# %%
pd.read_csv(path, encoding = 'cp949').shape
# Out:
# (319, 7)

# %%
pd.read_csv(path, encoding = 'cp949').sample()
# Out:
#          시군구 의료기관명  진료과수  병상수 국민안심병원 여부 감염병전담기관 여부 감염병전담기관 외래진료 가능여부
# 204  인천시 강화군  강화병원    13  160       NaN        NaN               NaN

# %%
pd.read_csv(path, encoding = 'cp949').columns
# Out:
# Index(['시군구', '의료기관명', '진료과수', '병상수', '국민안심병원 여부', '감염병전담기관 여부',
#        '감염병전담기관 외래진료 가능여부'],
#       dtype='object')

# %%
pd.read_csv(path, encoding = 'cp949').dtypes
# Out:
# 시군구                  object
# 의료기관명                object
# 진료과수                  int64
# 병상수                   int64
# 국민안심병원 여부            object
# 감염병전담기관 여부           object
# 감염병전담기관 외래진료 가능여부    object
# dtype: object

# %%
pd.read_csv(path, encoding = 'cp949').isnull()
# Out:
#        시군구  의료기관명   진료과수    병상수  국민안심병원 여부  감염병전담기관 여부  감염병전담기관 외래진료 가능여부
# 0    False  False  False  False       True        True               True
# 1    False  False  False  False       True        True               True
# 2    False  False  False  False       True        True               True
# 3    False  False  False  False       True        True               True
# 4    False  False  False  False      False        True               True
# ..     ...    ...    ...    ...        ...         ...                ...
# 314  False  False  False  False       True        True               True
# 315  False  False  False  False       True        True               True
# 316  False  False  False  False      False        True               True
# 317  False  False  False  False       True        True               True
# 318  False  False  False  False       True        True               True
#
# [319 rows x 7 columns]

# %%
null_count = pd.read_csv(path, encoding = 'cp949').isnull().sum()
df_null = null_count.reset_index()
df_null
# Out:
#                index    0
# 0                시군구    0
# 1              의료기관명    0
# 2               진료과수    0
# 3                병상수    0
# 4          국민안심병원 여부  247
# 5         감염병전담기관 여부  293
# 6  감염병전담기관 외래진료 가능여부  293

# %%
df_null.columns = ['메뉴', '결측']
df_null
# Out:
#                   메뉴   결측
# 0                시군구    0
# 1              의료기관명    0
# 2               진료과수    0
# 3                병상수    0
# 4          국민안심병원 여부  247
# 5         감염병전담기관 여부  293
# 6  감염병전담기관 외래진료 가능여부  293

# %%
df_null_3 = df_null.sort_values(by='결측', ascending=False).head(3)
df_null_3
# Out:
#                   메뉴   결측
# 5         감염병전담기관 여부  293
# 6  감염병전담기관 외래진료 가능여부  293
# 4          국민안심병원 여부  247

# %%
drop_columns = df_null_3['메뉴']
drop_columns
# Out:
# 5           감염병전담기관 여부
# 6    감염병전담기관 외래진료 가능여부
# 4            국민안심병원 여부
# Name: 메뉴, dtype: object

# %%
drop_columns.to_list()
# Out:
# ['감염병전담기관 여부', '감염병전담기관 외래진료 가능여부', '국민안심병원 여부']

# %%
pd.read_csv(path, encoding = 'cp949')[drop_columns]
# Out:
#     감염병전담기관 여부 감염병전담기관 외래진료 가능여부 국민안심병원 여부
# 0          NaN               NaN       NaN
# 1          NaN               NaN       NaN
# 2          NaN               NaN       NaN
# 3          NaN               NaN       NaN
# 4          NaN               NaN         Y
# ..         ...               ...       ...
# 314        NaN               NaN       NaN
# 315        NaN               NaN       NaN
# 316        NaN               NaN         Y
# 317        NaN               NaN       NaN
# 318        NaN               NaN       NaN
#
# [319 rows x 3 columns]

# %%
print(pd.read_csv(path, encoding = 'cp949').shape)
# Out:
# (319, 7)

# %%
df=pd.read_csv(path, encoding = 'cp949').drop(drop_columns, axis=1)

# %%
print(df.shape)
# Out:
# (319, 4)

# %%
df.head()
# Out:
#        시군구       의료기관명  진료과수  병상수
# 0  강원도 강릉시      강릉동인병원    21  608
# 1  강원도 강릉시     박정빈외과의원     1    0
# 2  강원도 강릉시     이명호내과의원     1    0
# 3  강원도 고성군       세브란의원     4    0
# 4  강원도 동해시  근로복지공단동해병원    10  499

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 4 columns):
# 시군구      319 non-null object
# 의료기관명    319 non-null object
# 진료과수     319 non-null int64
# 병상수      319 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 10.1+ KB
